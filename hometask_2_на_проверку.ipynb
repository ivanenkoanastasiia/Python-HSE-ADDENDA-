# %%
# задание 1 про "определитель усталости"

# 1.1 - добавьте условие, чтобы если пользователь вводит число больше 10, мы говорили ему, что так нельзя

a = float(input('по шкале от 0 до 10, напишите, насколько Вы устали: '))
if a < 0.7:
    print('Кажется, Вы совсем не устали!')
elif 0.7 <= a <= 6.8:
    print('Вы средненько устали!')
# мой код дальше (добавила диапазон + новое условие):
elif 6.8 < a <= 10:
    print("Кажется, вы сегодня просто ломовая лошадь!")
elif a > 10:
    print("Дружочек, максимум в этом определителе равен десяти!")

# 1.2 - добавьте еще одно или два условия, чтобы датчик категорий усталости был еще точнее
# добавлю еще два условия, разделив средний диапазон, который у нас был 

a = float(input('по шкале от 0 до 10, напишите, насколько Вы устали: '))
if a < 0.7:
    print('Кажется, Вы совсем не устали!')
elif 0.7 <= a <= 3:
    print('Отдыхать пока рано!')
elif 3 < a <= 5:
    print('Вы только начали уставать, поработайте еще!')
elif 5 < a <= 6.8:    
    print('Вы средненько устали!')
elif 6.8 < a <= 10:
    print('Кажется, вы сегодня просто ломовая лошадь!')
elif a > 10:
    print("Дружочек, максимум в этом определителе равен десяти!")

# %%
# задание 2 "цикл while"

# Напишите код, который будет считать от 100 до 0 с шагом в 10 и выводом промежуточных результатов на экран 
# Когда дойдет до финиша, на экран должно выводиться сообщение, что программа завершилась.

i = 100
print(i) 
while i > 0:
    i = i - 10
    print(i)
if i == 0: # не с первого раза поняла, что тут нужно ставить двойное равенство, а не одинарное. Какое тут правило? 
      print('завершение работы')

# %%
# задание 3 "модуль random и операции со строками"
# программа должна выбрать причину остаться дома и напечатать сообщение: "Сегодня я не иду на работу, потому что" и причину

import random
excuses = ["я устал","я улетел к океану","на улице холодно","на улице жарко", 
           "я в отпуске","у меня день рождения","сегодня выходной","мне надоело",
           "я работаю из дома","могу","плохо себя чувствую","не хочу", "у меня лапки","я в отпуске!",
           "на улице ураган"]
excuses.append("у меня ковид")
chosen_excuses = random.choice(excuses)
print("Сегодня я не иду на работу, потому что",chosen_excuses)
